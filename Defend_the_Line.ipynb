# %% [markdown]
# # Import

# %%
from vizdoom import *
import random
import time
import numpy as np
import gym
from gym import Env
from gym.spaces import Discrete, Box
import cv2
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback
import os
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common import policies
# import ppo for training
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# # Testing Defend the Line game

# %%
game = DoomGame()
game.load_config('VizDoom/scenarios/defend_the_line.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)

# %%
state = game.get_state()
state.game_variables
# Out:
# array([ 79., 100.])

# %%
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)
# Out:
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 4.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 2.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: -1.0
# Result: 10.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 2.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 7.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 2.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 9.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 11.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 13.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 11.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 7.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 1.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: 0.0
# reward: -1.0
# Result: 7.0

# %%
game.close()

# %% [markdown]
# # Set-up openAI framework

# %%
import torch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")          # a CUDA device object
    print('CUDA is available on this device!')
else:
    device = torch.device("cpu")           # a CPU device object
    print('CUDA is not available on this device :(')
# Out:
# CUDA is available on this device!

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
# Create DOOM OpenAI Gym SIMPLE Environment
class VizDoomGym(Env): 
    def __init__(self, render=False): 
        super().__init__()
        self.game = DoomGame()
         
        #load basic configuration for simple environment
        self.game.load_config('VizDoom/scenarios/defend_the_line.cfg')
        
        #Set visibility of game
        if render == True: 
            self.game.set_window_visible(True)
        else:
            self.game.set_window_visible(False)
        
        # Start the game 
        self.game.init()
        
        # Create observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        
        # Create action space
        self.action_space = Discrete(3)
        
    # Create Step function
    def step(self, action):
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get information from the game
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Render
    def render(): 
        pass
    
    # Reset game
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()

# %%
env.close()

# %% [markdown]
# # Create Callback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %% [markdown]
# # Hyper parameter Tuning

# %%
import optuna

# %%
def optimise_ppo(trial):
    """ Learning hyperparamters we want to optimise"""
    return {
        'n_steps': int(trial.suggest_loguniform('n_steps', 32, 8192)),
        'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 0.1),
        'ent_coef': trial.suggest_loguniform('ent_coef', 1e-8, 1e-1),
    }

def optimise_agent(trial):
    model_params = optimise_ppo(trial)
    env = VizDoomGym(render=False)
    model = PPO('CnnPolicy', env, verbose =1, **model_params)
    model.learn(25000)
    
    
    rewards = []
    n_episodes, reward_sum = 0, 0.0

    obs = env.reset()
    while n_episodes < 4:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        reward_sum += reward

        if done:
            rewards.append(reward_sum)
            reward_sum = 0.0
            n_episodes += 1
            obs = env.reset()

    last_reward = np.mean(rewards)

    return -1 * last_reward

# %%
study = optuna.create_study()
# Out:
# [I 2023-04-09 15:25:43,637] A new study created in memory with name: no-name-6d4be987-228b-4b45-b61e-2a71da58391a

# %%
study.optimize(optimise_agent, n_trials = 15)
# Out:
# C:\Users\Ga401\AppData\Local\Temp\ipykernel_19272\3852764674.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'n_steps': int(trial.suggest_loguniform('n_steps', 32, 8192)),
# C:\Users\Ga401\AppData\Local\Temp\ipykernel_19272\3852764674.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 0.1),
# C:\Users\Ga401\AppData\Local\Temp\ipykernel_19272\3852764674.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'ent_coef': trial.suggest_loguniform('ent_coef', 1e-8, 1e-1),
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# C:\Users\Ga401\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:145: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 100`, after every 1 untruncated mini-batches, there will be a truncated mini-batch of size 36
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=100 and n_envs=1)
#   warnings.warn(
# ----------------------------
# | time/              |     |
# |    fps             | 11  |
# |    iterations      | 1   |
# |    time_elapsed    | 8   |
# |    total_timesteps | 100 |
# ----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | 8           |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 200         |
# | train/                  |             |
# |    approx_kl            | 0.019648336 |
# |    clip_fraction        | 0.476       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.0767      |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.144       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.033       |
# |    value_loss           | 6.9e+04     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 119          |
# |    ep_rew_mean          | 7.5          |
# | time/                   |              |
# |    fps                  | 18           |
# |    iterations           | 3            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 300          |
# | train/                  |              |
# |    approx_kl            | 0.0111950915 |
# |    clip_fraction        | 0.248        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000306     |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.635        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.013       |
# |    value_loss           | 1.42         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 8           |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 400         |
# | train/                  |             |
# |    approx_kl            | 0.015412199 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.000199    |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.347       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 0.745       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 128        |
# |    ep_rew_mean          | 8          |
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 5          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 500        |
# | train/                  |            |
# |    approx_kl            | 0.01411026 |
# |    clip_fraction        | 0.279      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 9.41e-05   |
# |    learning_rate        | 0.014      |
# |    loss                 | 0.308      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0282    |
# |    value_loss           | 0.998      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 7.75         |
# | time/                   |              |
# |    fps                  | 24           |
# |    iterations           | 6            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 600          |
# | train/                  |              |
# |    approx_kl            | 0.0074620564 |
# |    clip_fraction        | 0.228        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.0155      |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.151        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | 0.00536      |
# |    value_loss           | 0.339        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 137        |
# |    ep_rew_mean          | 8.4        |
# | time/                   |            |
# |    fps                  | 26         |
# |    iterations           | 7          |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 700        |
# | train/                  |            |
# |    approx_kl            | 0.33742684 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.961     |
# |    explained_variance   | -0.00615   |
# |    learning_rate        | 0.014      |
# |    loss                 | 12         |
# |    n_updates            | 60         |
# |    policy_gradient_loss | 0.0281     |
# |    value_loss           | 3.67       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 8.4         |
# | time/                   |             |
# |    fps                  | 27          |
# |    iterations           | 8           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 800         |
# | train/                  |             |
# |    approx_kl            | 0.008825367 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.585       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 0.882       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 8.17        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 900         |
# | train/                  |             |
# |    approx_kl            | 0.017528947 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.125       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 0.394       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 7.86        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 10          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 1000        |
# | train/                  |             |
# |    approx_kl            | 0.014214834 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.643       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 1.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 6.44        |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 11          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 1100        |
# | train/                  |             |
# |    approx_kl            | 0.010103601 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.632       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 1           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 114          |
# |    ep_rew_mean          | 6            |
# | time/                   |              |
# |    fps                  | 28           |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 1200         |
# | train/                  |              |
# |    approx_kl            | 0.0053019086 |
# |    clip_fraction        | 0.176        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.523        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00582     |
# |    value_loss           | 1.32         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 114        |
# |    ep_rew_mean          | 6          |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 13         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 1300       |
# | train/                  |            |
# |    approx_kl            | 0.03677368 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.014      |
# |    loss                 | 0.554      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0152    |
# |    value_loss           | 0.948      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 120         |
# |    ep_rew_mean          | 6.27        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 14          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 1400        |
# | train/                  |             |
# |    approx_kl            | 0.014071818 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.136       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00888    |
# |    value_loss           | 0.325       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 6.42        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 15          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 1500        |
# | train/                  |             |
# |    approx_kl            | 0.010174769 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.733       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 1.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 6.42        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 16          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 1600        |
# | train/                  |             |
# |    approx_kl            | 0.021856919 |
# |    clip_fraction        | 0.384       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.528       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 1.55        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 124        |
# |    ep_rew_mean          | 6.62       |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 17         |
# |    time_elapsed         | 56         |
# |    total_timesteps      | 1700       |
# | train/                  |            |
# |    approx_kl            | 0.02673278 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.93      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.014      |
# |    loss                 | 0.305      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0117    |
# |    value_loss           | 0.61       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 7.07        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 18          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 1800        |
# | train/                  |             |
# |    approx_kl            | 0.017821033 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.767       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.008      |
# |    value_loss           | 1.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 128         |
# |    ep_rew_mean          | 7.07        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 19          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 1900        |
# | train/                  |             |
# |    approx_kl            | 0.010339139 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.722       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 1.54        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 127        |
# |    ep_rew_mean          | 6.87       |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 20         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 2000       |
# | train/                  |            |
# |    approx_kl            | 0.01849546 |
# |    clip_fraction        | 0.146      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.972     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.014      |
# |    loss                 | 0.0833     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.00383   |
# |    value_loss           | 0.212      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 7           |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 21          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 2100        |
# | train/                  |             |
# |    approx_kl            | 0.017182516 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.29        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 0.639       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 7           |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 22          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 2200        |
# | train/                  |             |
# |    approx_kl            | 0.007669237 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.874      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.89        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.000178    |
# |    value_loss           | 1.49        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 130        |
# |    ep_rew_mean          | 7.65       |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 23         |
# |    time_elapsed         | 74         |
# |    total_timesteps      | 2300       |
# | train/                  |            |
# |    approx_kl            | 0.01027423 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.674     |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.014      |
# |    loss                 | 0.425      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00678   |
# |    value_loss           | 1.3        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 130        |
# |    ep_rew_mean          | 7.65       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 24         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 2400       |
# | train/                  |            |
# |    approx_kl            | 0.01508531 |
# |    clip_fraction        | 0.0793     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.714     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.014      |
# |    loss                 | 1.07       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00219   |
# |    value_loss           | 1.97       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | 8.28        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 25          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 2500        |
# | train/                  |             |
# |    approx_kl            | 0.008099489 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.242       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00676    |
# |    value_loss           | 0.613       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 8.11        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 26          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 2600        |
# | train/                  |             |
# |    approx_kl            | 0.029597633 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.625      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.84        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 2.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 8.11         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 27           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 2700         |
# | train/                  |              |
# |    approx_kl            | 0.0030438663 |
# |    clip_fraction        | 0.0931       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.8          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000754    |
# |    value_loss           | 1.91         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 8.1          |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 28           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 2800         |
# | train/                  |              |
# |    approx_kl            | 0.0013669987 |
# |    clip_fraction        | 0.00825      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.0993       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.00139      |
# |    value_loss           | 0.22         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 134           |
# |    ep_rew_mean          | 7.81          |
# | time/                   |               |
# |    fps                  | 31            |
# |    iterations           | 29            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 2900          |
# | train/                  |               |
# |    approx_kl            | 0.00030639814 |
# |    clip_fraction        | 0.0648        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.549        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.014         |
# |    loss                 | 0.36          |
# |    n_updates            | 280           |
# |    policy_gradient_loss | 0.00193       |
# |    value_loss           | 1.16          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | 7.68         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 30           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 3000         |
# | train/                  |              |
# |    approx_kl            | 0.0017156568 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.688        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000347     |
# |    value_loss           | 1.59         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 132          |
# |    ep_rew_mean          | 7.65         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 31           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 3100         |
# | train/                  |              |
# |    approx_kl            | 0.0052456437 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.296        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000517    |
# |    value_loss           | 0.355        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | 7.58        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 32          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 3200        |
# | train/                  |             |
# |    approx_kl            | 0.005760384 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 1.05        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 1.8         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 7.52        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 33          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 3300        |
# | train/                  |             |
# |    approx_kl            | 0.013939753 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 1.05        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 1.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 129          |
# |    ep_rew_mean          | 7.54         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 34           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 3400         |
# | train/                  |              |
# |    approx_kl            | 0.0044791196 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.422       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.656        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00326     |
# |    value_loss           | 1.59         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 129         |
# |    ep_rew_mean          | 7.54        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 35          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 3500        |
# | train/                  |             |
# |    approx_kl            | 0.028571978 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 1.28        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 1.94        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 129          |
# |    ep_rew_mean          | 7.54         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 36           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 3600         |
# | train/                  |              |
# |    approx_kl            | 0.0003792541 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.533       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.141        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.0014       |
# |    value_loss           | 0.508        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | 8.04         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 37           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 3700         |
# | train/                  |              |
# |    approx_kl            | 0.0025189389 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.106        |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 0.232        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 134          |
# |    ep_rew_mean          | 8.04         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 38           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 3800         |
# | train/                  |              |
# |    approx_kl            | 0.0057224957 |
# |    clip_fraction        | 0.0264       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.536       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 1.61         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 1.72         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 136          |
# |    ep_rew_mean          | 8.18         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 39           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 3900         |
# | train/                  |              |
# |    approx_kl            | 0.0037837874 |
# |    clip_fraction        | 0.0622       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.104        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 0.251        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 8.24         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 40           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 4000         |
# | train/                  |              |
# |    approx_kl            | 0.0052777594 |
# |    clip_fraction        | 0.0923       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 1.28         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0088      |
# |    value_loss           | 3.01         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 137          |
# |    ep_rew_mean          | 8.24         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 41           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 4100         |
# | train/                  |              |
# |    approx_kl            | 0.0033842432 |
# |    clip_fraction        | 0.00747      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.531       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.384        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00029     |
# |    value_loss           | 2.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 8.3          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 42           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 4200         |
# | train/                  |              |
# |    approx_kl            | 0.0032455812 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.0672       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 0.192        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 8.19         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 43           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 4300         |
# | train/                  |              |
# |    approx_kl            | 0.0083174985 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.423        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000981     |
# |    value_loss           | 0.987        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 138           |
# |    ep_rew_mean          | 8.19          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 44            |
# |    time_elapsed         | 134           |
# |    total_timesteps      | 4400          |
# | train/                  |               |
# |    approx_kl            | 0.00076808035 |
# |    clip_fraction        | 0.0578        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.588        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.014         |
# |    loss                 | 1.29          |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.0016       |
# |    value_loss           | 2.22          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 8.31         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 45           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 4500         |
# | train/                  |              |
# |    approx_kl            | 0.0025719206 |
# |    clip_fraction        | 0.085        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.465       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.148        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00649     |
# |    value_loss           | 0.377        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 138          |
# |    ep_rew_mean          | 8.27         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 46           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 4600         |
# | train/                  |              |
# |    approx_kl            | 0.0015093416 |
# |    clip_fraction        | 0.0427       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.562       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 1.12         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00515     |
# |    value_loss           | 2.33         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 138        |
# |    ep_rew_mean          | 8.27       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 47         |
# |    time_elapsed         | 142        |
# |    total_timesteps      | 4700       |
# | train/                  |            |
# |    approx_kl            | 0.00703064 |
# |    clip_fraction        | 0.056      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.559     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.014      |
# |    loss                 | 0.958      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00631   |
# |    value_loss           | 2.47       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 139          |
# |    ep_rew_mean          | 8.41         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 48           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 4800         |
# | train/                  |              |
# |    approx_kl            | 0.0023403694 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.579       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.014        |
# |    loss                 | 0.404        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000857    |
# |    value_loss           | 0.878        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 139        |
# |    ep_rew_mean          | 8.41       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 49         |
# |    time_elapsed         | 148        |
# |    total_timesteps      | 4900       |
# | train/                  |            |
# |    approx_kl            | 0.03404548 |
# |    clip_fraction        | 0.101      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.49      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.014      |
# |    loss                 | 0.954      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 2.29       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 8.57        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 50          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 5000        |
# | train/                  |             |
# |    approx_kl            | 0.001041262 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.176       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.000133    |
# |    value_loss           | 0.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 8.57        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 51          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 5100        |
# | train/                  |             |
# |    approx_kl            | 0.002927607 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.475      |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.014       |
# |    loss                 | 1.09        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 2.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | 8.83        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 52          |
# |    time_elapsed         | 156         |
# |    total_timesteps      | 5200        |
# | train/                  |             |
# |    approx_kl            | 0.001473557 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.442      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.014       |
# |    loss                 | 0.24        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 0.000428    |
# |    value_loss           | 0.698       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 143        |
# |    ep_rew_mean          | 8.83       |
# | time/                   |            |
# |    fps                  | 33         |
# |    iterations           | 53         |
# |    time_elapsed         | 159        |
# |    total_timesteps      | 5300       |
# | train/                  |            |
# |    approx_kl            | 0.05209808 |
# |    clip_fraction        | 0.0754     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.388     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.014      |
# |    loss                 | 1.82       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00216   |
# |    value_loss           | 2.59       |
# ----------------------------------------
# ------------------------------------------
# ...
# |    total_timesteps      | 12576       |
# | train/                  |             |
# |    approx_kl            | 0.011819009 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.995      |
# |    explained_variance   | 0.515       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.0926      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 0.576       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 10.3        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 9           |
# |    time_elapsed         | 421         |
# |    total_timesteps      | 14148       |
# | train/                  |             |
# |    approx_kl            | 0.007437085 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.205       |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 0.598       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | 10.9        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 10          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 15720       |
# | train/                  |             |
# |    approx_kl            | 0.008868632 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.156       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.593       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 11          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 17292       |
# | train/                  |             |
# |    approx_kl            | 0.012893052 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.93       |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.0436      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 0.629       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 12.8        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 12          |
# |    time_elapsed         | 572         |
# |    total_timesteps      | 18864       |
# | train/                  |             |
# |    approx_kl            | 0.006553729 |
# |    clip_fraction        | 0.0615      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.133       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0174     |
# |    value_loss           | 0.536       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 13.8        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 13          |
# |    time_elapsed         | 620         |
# |    total_timesteps      | 20436       |
# | train/                  |             |
# |    approx_kl            | 0.008440963 |
# |    clip_fraction        | 0.0739      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.148       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 0.563       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 14          |
# |    time_elapsed         | 670         |
# |    total_timesteps      | 22008       |
# | train/                  |             |
# |    approx_kl            | 0.007862907 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.774       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.105       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.636       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 182         |
# |    ep_rew_mean          | 15.7        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 15          |
# |    time_elapsed         | 722         |
# |    total_timesteps      | 23580       |
# | train/                  |             |
# |    approx_kl            | 0.010958775 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.852      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.0841      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 0.45        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 187         |
# |    ep_rew_mean          | 16.4        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 16          |
# |    time_elapsed         | 774         |
# |    total_timesteps      | 25152       |
# | train/                  |             |
# |    approx_kl            | 0.010832259 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 7.72e-05    |
# |    loss                 | 0.0894      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.475       |
# -----------------------------------------
# [I 2023-04-09 18:37:17,840] Trial 13 finished with value: -21.5 and parameters: {'n_steps': 1572.287364978795, 'learning_rate': 7.723552611093095e-05, 'ent_coef': 0.00010022639267441021}. Best is trial 13 with value: -21.5.
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# C:\Users\Ga401\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:145: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3081`, after every 48 untruncated mini-batches, there will be a truncated mini-batch of size 9
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3081 and n_envs=1)
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 6.84     |
# | time/              |          |
# |    fps             | 31       |
# |    iterations      | 1        |
# |    time_elapsed    | 97       |
# |    total_timesteps | 3081     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 130         |
# |    ep_rew_mean          | 7.49        |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 2           |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 6162        |
# | train/                  |             |
# |    approx_kl            | 0.008718398 |
# |    clip_fraction        | 0.019       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00778    |
# |    learning_rate        | 6.65e-05    |
# |    loss                 | 0.0624      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 7.55         |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 3            |
# |    time_elapsed         | 310          |
# |    total_timesteps      | 9243         |
# | train/                  |              |
# |    approx_kl            | 0.0068044025 |
# |    clip_fraction        | 0.0575       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.365        |
# |    learning_rate        | 6.65e-05     |
# |    loss                 | -0.000104    |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 0.359        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 8.4         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 4           |
# |    time_elapsed         | 412         |
# |    total_timesteps      | 12324       |
# | train/                  |             |
# |    approx_kl            | 0.010475553 |
# |    clip_fraction        | 0.0695      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.488       |
# |    learning_rate        | 6.65e-05    |
# |    loss                 | 0.0883      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0168     |
# |    value_loss           | 0.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 9.77        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 5           |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 15405       |
# | train/                  |             |
# |    approx_kl            | 0.013801666 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.568       |
# |    learning_rate        | 6.65e-05    |
# |    loss                 | 0.301       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 0.517       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 157         |
# |    ep_rew_mean          | 11.2        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 6           |
# |    time_elapsed         | 629         |
# |    total_timesteps      | 18486       |
# | train/                  |             |
# |    approx_kl            | 0.011754282 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 6.65e-05    |
# |    loss                 | 0.0547      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.473       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | 12.5        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 7           |
# |    time_elapsed         | 733         |
# |    total_timesteps      | 21567       |
# | train/                  |             |
# |    approx_kl            | 0.010970222 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 6.65e-05    |
# |    loss                 | 0.176       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0241     |
# |    value_loss           | 0.479       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 173        |
# |    ep_rew_mean          | 13.9       |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 8          |
# |    time_elapsed         | 839        |
# |    total_timesteps      | 24648      |
# | train/                  |            |
# |    approx_kl            | 0.01328301 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.981     |
# |    explained_variance   | 0.746      |
# |    learning_rate        | 6.65e-05   |
# |    loss                 | 0.0221     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0248    |
# |    value_loss           | 0.534      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 185         |
# |    ep_rew_mean          | 15.6        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 9           |
# |    time_elapsed         | 942         |
# |    total_timesteps      | 27729       |
# | train/                  |             |
# |    approx_kl            | 0.010054714 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 6.65e-05    |
# |    loss                 | 0.0361      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 0.533       |
# -----------------------------------------
# [I 2023-04-09 18:53:33,060] Trial 14 finished with value: -17.5 and parameters: {'n_steps': 3081.853261557502, 'learning_rate': 6.647532992254155e-05, 'ent_coef': 0.00021931700027353205}. Best is trial 13 with value: -21.5.

# %%
print(study.best_params)
# Out:
# {'n_steps': 1572.287364978795, 'learning_rate': 7.723552611093095e-05, 'ent_coef': 0.00010022639267441021}

# %% [markdown]
# # Training Agent

# %%
env = VizDoomGym(False)

# %%
CHECKPOINT_DIR = './model/line_model/PPO_model_line/'
LOG_DIR = './model_log/log_line'

callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1,
            learning_rate=0.0001, n_steps=4096, batch_size = 64, 
            ent_coef=0.00001)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=150000, callback=callback)
# Out:
# Logging to ./model_log/log_line\PPO_4
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 146      |
# |    ep_rew_mean     | 8.54     |
# | time/              |          |
# |    fps             | 35       |
# |    iterations      | 1        |
# |    time_elapsed    | 116      |
# |    total_timesteps | 4096     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | 8.62         |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 2            |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0066586914 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.0223      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0943       |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00662     |
# |    value_loss           | 0.272        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 148         |
# |    ep_rew_mean          | 9.57        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 3           |
# |    time_elapsed         | 370         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014053198 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.092       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0268     |
# |    value_loss           | 0.347       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | 10.9        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 4           |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017346304 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0519      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0343     |
# |    value_loss           | 0.364       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 168         |
# |    ep_rew_mean          | 12.6        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 5           |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017052863 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0348      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0348     |
# |    value_loss           | 0.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 14.7        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 6           |
# |    time_elapsed         | 746         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015453902 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0258      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 0.436       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | 16.5        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 7           |
# |    time_elapsed         | 868         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017397787 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.974      |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0486      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0339     |
# |    value_loss           | 0.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 8           |
# |    time_elapsed         | 990         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018660583 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.953      |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.039       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 0.388       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 205        |
# |    ep_rew_mean          | 18.6       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 9          |
# |    time_elapsed         | 1124       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.01819778 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.932     |
# |    explained_variance   | 0.832      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.1        |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0354    |
# |    value_loss           | 0.419      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 208         |
# |    ep_rew_mean          | 19.1        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 10          |
# |    time_elapsed         | 1249        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.019635826 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0863      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 0.446       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 206         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 11          |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018592346 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0146      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0395     |
# |    value_loss           | 0.453       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 205         |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 12          |
# |    time_elapsed         | 1506        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.020681828 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0514      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.041      |
# |    value_loss           | 0.475       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 204         |
# |    ep_rew_mean          | 19.3        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 13          |
# |    time_elapsed         | 1632        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.025353376 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0531      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0398     |
# |    value_loss           | 0.422       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 203         |
# |    ep_rew_mean          | 19.4        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 14          |
# |    time_elapsed         | 1751        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.023022722 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.014       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 0.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 208         |
# |    ep_rew_mean          | 20.2        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 15          |
# |    time_elapsed         | 1885        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.023971863 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0684      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 0.474       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | 20.4        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 16          |
# |    time_elapsed         | 2016        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.023769196 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.862       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0217      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.043      |
# |    value_loss           | 0.436       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 215         |
# |    ep_rew_mean          | 21.1        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 17          |
# |    time_elapsed         | 2148        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.028968375 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.758      |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00399     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0444     |
# |    value_loss           | 0.397       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 216        |
# |    ep_rew_mean          | 21.5       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 18         |
# |    time_elapsed         | 2273       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02683732 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.731     |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0535     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0429    |
# |    value_loss           | 0.399      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 222         |
# |    ep_rew_mean          | 22.2        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 19          |
# |    time_elapsed         | 2397        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.025806447 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.75       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.000738    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0432     |
# |    value_loss           | 0.424       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 224        |
# |    ep_rew_mean          | 22.5       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 20         |
# |    time_elapsed         | 2520       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02697077 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.745     |
# |    explained_variance   | 0.885      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0338     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0426    |
# |    value_loss           | 0.471      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 229         |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 21          |
# |    time_elapsed         | 2646        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.028042808 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.023      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0438     |
# |    value_loss           | 0.429       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 228         |
# |    ep_rew_mean          | 23.1        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 22          |
# |    time_elapsed         | 2778        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.028948242 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.666      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0328      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0434     |
# |    value_loss           | 0.386       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 227         |
# |    ep_rew_mean          | 23          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 23          |
# |    time_elapsed         | 2901        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.030046318 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0248     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0414     |
# |    value_loss           | 0.362       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 233        |
# |    ep_rew_mean          | 23.7       |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 24         |
# |    time_elapsed         | 3044       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.03072752 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.636     |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0219    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0451    |
# |    value_loss           | 0.379      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 234         |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 25          |
# |    time_elapsed         | 3168        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.033415034 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.583      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0361      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0396     |
# |    value_loss           | 0.333       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 235         |
# |    ep_rew_mean          | 24.4        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 26          |
# |    time_elapsed         | 3294        |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.032098033 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00779    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 0.354       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 231         |
# |    ep_rew_mean          | 24          |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 27          |
# |    time_elapsed         | 3451        |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.030777713 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.585      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0255     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0403     |
# |    value_loss           | 0.365       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 242       |
# |    ep_rew_mean          | 25.1      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 28        |
# |    time_elapsed         | 3608      |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.0353581 |
# |    clip_fraction        | 0.227     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.597    |
# |    explained_variance   | 0.909     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 0.00584   |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -0.0447   |
# |    value_loss           | 0.374     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 25.8        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 29          |
# |    time_elapsed         | 3732        |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.034130264 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0256      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0432     |
# |    value_loss           | 0.344       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 249         |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 30          |
# |    time_elapsed         | 3887        |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.032743745 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.579      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0119      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0429     |
# |    value_loss           | 0.395       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 250         |
# |    ep_rew_mean          | 26.1        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 31          |
# |    time_elapsed         | 4007        |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.036218636 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00316     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0454     |
# |    value_loss           | 0.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 246         |
# |    ep_rew_mean          | 25.6        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 32          |
# |    time_elapsed         | 4163        |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.038934406 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.592      |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0077      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0444     |
# |    value_loss           | 0.382       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 245        |
# |    ep_rew_mean          | 25.6       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 33         |
# |    time_elapsed         | 4287       |
# |    total_timesteps      | 135168     |
# | train/                  |            |
# |    approx_kl            | 0.03539692 |
# |    clip_fraction        | 0.239      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.596     |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.015      |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0449    |
# |    value_loss           | 0.443      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 238        |
# |    ep_rew_mean          | 24.9       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 34         |
# |    time_elapsed         | 4413       |
# |    total_timesteps      | 139264     |
# | train/                  |            |
# |    approx_kl            | 0.03704555 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.607     |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00516   |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.046     |
# |    value_loss           | 0.429      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 230        |
# |    ep_rew_mean          | 24.1       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 35         |
# |    time_elapsed         | 4555       |
# |    total_timesteps      | 143360     |
# | train/                  |            |
# |    approx_kl            | 0.03706271 |
# |    clip_fraction        | 0.245      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.602     |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.049     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0471    |
# |    value_loss           | 0.398      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 227        |
# |    ep_rew_mean          | 23.7       |
# | time/                   |            |
# |    fps                  | 31         |
# |    iterations           | 36         |
# |    time_elapsed         | 4681       |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.03625565 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.586     |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.046      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0422    |
# |    value_loss           | 0.48       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 227         |
# |    ep_rew_mean          | 23.6        |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 37          |
# |    time_elapsed         | 4811        |
# |    total_timesteps      | 151552      |
# | train/                  |             |
# |    approx_kl            | 0.039865993 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0152      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 0.521       |
# -----------------------------------------

# %%
import gc
torch.cuda.empty_cache()
gc.collect()

# %% [markdown]
# # Evaluate

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disc
model = PPO.load('./model/line_model/PPO_model_line/model_150000')

# %%
import gc
torch.cuda.empty_cache()
gc.collect()

# %%
# Create rendered environment
env = VizDoomGym(render=False)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=100)

# %%
mean_reward

# %%
# Create rendered environment
env = VizDoomGym(render=True)

# %%
for episode in range(10): 
    obs = env.reset()
    done = False
    result_reward = 0
    while not done: 
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        # time.sleep(0.20)
        result_reward += reward
    print('Episode {}: Total Reward is {}'.format(episode, result_reward))
    time.sleep(1)
# Out:
# Total Reward for episode 23.0 is 0
# Total Reward for episode 26.0 is 1
# Total Reward for episode 29.0 is 2
# Total Reward for episode 25.0 is 3
# Total Reward for episode 23.0 is 4
# Total Reward for episode 40.0 is 5
# Total Reward for episode 27.0 is 6
# Total Reward for episode 35.0 is 7
# Total Reward for episode 31.0 is 8
# Total Reward for episode 23.0 is 9
